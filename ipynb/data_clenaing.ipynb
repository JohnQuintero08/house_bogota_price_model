# %%
import json
import pandas as pd
import numpy as np
import re

# %%
pd.set_option('display.max_columns', None)

# %%
with open('../data/raw_houses_data.json', 'r', encoding='utf-8') as f:
    datos = json.load(f)
print(datos)
# Out:
# [{'location': 'Minuto de dios, Bogotá, Bogotá, d.c.', 'price': '$ 700.000.000', 'details': ['3', 'Casa', '¡Pregúntale!', '3', '216.00  m2', '200.00  m2', '16 a 30 años', '6'], 'comodities': ['Baño Auxiliar', 'Calentador', 'Canchas Deportivas', 'Cocina tipo Americano', 'Colegios / Universidades', 'Estudio', 'Garaje(s)', 'Jardín', 'Parques cercanos', 'Patio', 'Supermercados / C.Comerciales', 'Trans. Público cercano', 'Zona Comercial', 'Zona de lavandería', 'Zona Residencial', 'Zonas Verdes'], 'code': ['Código Fincaraíz: ', '192044144'], 'real_state_agent': ['Casa en  Venta es una Casa con 6 habitaciones, 3 baños y 216 m². Esta propiedad se encuentra disponible a la venta y fue ingresada por LUZ PATRICIA GONZALEZ el 19 de febrero de 2025. El precio de Venta es de $ 700.000.000']}, {'location': 'Alhambra, Bogotá, Bogotá, d.c.', 'price': '$ 650.000.000', 'details': ['5', 'Casa', '¡Pregúntale!', '3', '186.98  m2', '186.98  m2', '16 a 30 años', '3'], 'comodities': ['Baño Auxiliar', 'Calentador', 'Canchas Deportivas', 'Cocina Integral', 'Cuarto de servicio', 'Estudio', 'Parques cercanos', 'Patio', 'Trans. Público cercano', 'Zona de lavandería', 'Zona Residencial', 'Zonas Verdes'], 'code': ['Código Fincaraíz: ', '191482926'], 'real_state_agent': ['Casa en  Venta es una Casa con 3 habitaciones, 3 baños y 186.98 m². Esta propiedad se encuentra disponible a la venta y fue ingresada por ALU REAL ESTATE GROUP el 26 de septiembre de 2024. El precio de Venta es de $ 650.000.000']}, {'location': 'Engativá, Bogotá, Bogotá, d.c.', 'price': '$ 1.100.000.000', 'details': ['4', 'Casa', 'Excelente estado', '4', '321.00  m2', '321.00  m2', 'más de 30 años', '7'], 'comodities': ['Cerca a sector comercial', 'Cerca centro comercial', 'Cómodas vias de acceso', 'Parques cercanos', 'Piso en Baldosa /  Mármol', 'Sobre vía secundaria', 'Trans. Público cercano', 'Zona Residencial'], 'code': ['Código Fincaraíz: ', '192079025'], 'real_state_agent': ['Casa en  Venta es una Casa con 7 habitaciones, 4 baños y 321 m². Esta propiedad se encuentra disponible a la venta y fue ingresada por GRUPO EMPRESARIAL OIKOS S.A.S el 27 de febrero de 2025. El precio de Venta es de $ 1.100.000.000']}, {'location': 'Pinar de Suba, Bogotá, Bogotá, d.c.', 'price': '$ 255.000.000', 'details': ['3', 'Casa', '¡Pregúntale!', '2', '60.00  m2', '58.00  m2', '16 a 30 años', '4'], 'comodities': ['Cocina Integral', 'Colegios / Universidades', 'En conjunto cerrado', 'Jardín', 'Parqueadero Visitantes', 'Parques cercanos', 'Patio', 'Piso en Baldosa /  Mármol', 'Portería / Recepción', 'Salón Comunal', 'Supermercados / C.Comerciales', 'Trans. Público cercano', 'Zona de lavandería', 'Zona Infantil', 'Zona Residencial', 'Zonas Verdes'], 'code': ['Código Fincaraíz: ', '192307407'], 'real_state_agent': ['Casa en Venta en Pinar de Suba, Bogotá es una Casa con 4 habitaciones, 2 baños y 60 m². Esta propiedad se encuentra disponible a la venta y fue ingresada por VIVIENDA 360 el 24 de abril de 2025. El precio de Venta es de $ 255.000.000']}, {'location': 'Tunjuelito, Bogotá, Bogotá, d.c.', 'price': '$ 550.000.000', 'details': ['2', 'Casa', '¡Pregúntale!', '3', '228.00  m2', '¡Pregúntale!', 'más de 30 años', '6'], 'comodities': ['Sobre vía principal', 'Zona Residencial'], 'code': ['Código Fincaraíz: ', '192313340'], 'real_state_agent': ['Casa en Venta es una Casa con 6 habitaciones, 3 baños y 228 m². Esta propiedad se encuentra disponible a la venta y fue ingresada por INMOBELENA el 26 de abril de 2025. El precio de Venta es de $ 550.000.000']}, {'location': 'Las lomas, Bogotá, Bogotá, d.c.', 'price': '$ 340.000.000', 'details': ['2', 'Casa', '¡Pregúntale!', '3', '128.00  m2', '128.00  m2', 'más de 30 años', '5'], 'comodities': [], 'code': ['Código Fincaraíz: ', '10403404'], 'real_state_agent': ['Casa en venta es una Casa con 5 habitaciones, 3 baños y 128 m². Esta propiedad se encuentra disponible a la venta y fue ingresada por MYHAUS INMOBILIARIA SAS el 29 de diciembre de 2023. El precio de Venta es de $  ...

# %%
df = pd.DataFrame(datos)
df.head()
# Out:
#                                location            price  \
# 0  Minuto de dios, Bogotá, Bogotá, d.c.    $ 700.000.000
# 1        Alhambra, Bogotá, Bogotá, d.c.    $ 650.000.000
# 2        Engativá, Bogotá, Bogotá, d.c.  $ 1.100.000.000
# 3   Pinar de Suba, Bogotá, Bogotá, d.c.    $ 255.000.000
# 4      Tunjuelito, Bogotá, Bogotá, d.c.    $ 550.000.000
#
#                                              details  \
# 0  [3, Casa, ¡Pregúntale!, 3, 216.00  m2, 200.00 ...
# 1  [5, Casa, ¡Pregúntale!, 3, 186.98  m2, 186.98 ...
# 2  [4, Casa, Excelente estado, 4, 321.00  m2, 321...
# 3  [3, Casa, ¡Pregúntale!, 2, 60.00  m2, 58.00  m...
# 4  [2, Casa, ¡Pregúntale!, 3, 228.00  m2, ¡Pregún...
#
#                                           comodities  \
# 0  [Baño Auxiliar, Calentador, Canchas Deportivas...
# 1  [Baño Auxiliar, Calentador, Canchas Deportivas...
# 2  [Cerca a sector comercial, Cerca centro comerc...
# 3  [Cocina Integral, Colegios / Universidades, En...
# 4            [Sobre vía principal, Zona Residencial]
#
#                               code  \
# 0  [Código Fincaraíz: , 192044144]
# 1  [Código Fincaraíz: , 191482926]
# 2  [Código Fincaraíz: , 192079025]
# 3  [Código Fincaraíz: , 192307407]
# 4  [Código Fincaraíz: , 192313340]
#
#                                     real_state_agent
# 0  [Casa en  Venta es una Casa con 6 habitaciones...
# 1  [Casa en  Venta es una Casa con 3 habitaciones...
# 2  [Casa en  Venta es una Casa con 7 habitaciones...
# 3  [Casa en Venta en Pinar de Suba, Bogotá es una...
# 4  [Casa en Venta es una Casa con 6 habitaciones,...

# %%
def transform_location(raw_location):
    try:
        neighbourhood = raw_location.split(',')[0]
        return neighbourhood
    except:
        return np.nan

# %%
def transform_price(raw_price):
    try:
        price = raw_price.replace('$','').strip()
        price = int(price.replace('.',''))
        return price
    except:
        return np.nan

# %%
def transform_detail_to(raw_detail, loc):
    try:
        data = raw_detail[loc]
        if data == '¡Pregúntale!' or data == 'Sin Definir':
            return np.nan
        else:
            return data.strip()
    except:
        return np.nan

# %%
def transform_detail_to_area(raw_detail, loc):
    try:
        return float(raw_detail[loc].split(' ')[0])
    except:
        return np.nan

# %%
def transform_code(raw_code):
    try:
        return raw_code[1]
    except:
        return np.nan

# %%
def transform_agent(raw_agent):
    try:
        pattern = r"ingresada por(.*?) el"
        result = re.search(pattern, raw_agent[0])
        return result.group(1).strip().lower()
    except:
        return np.nan

# %%
def transform_date(raw_agent):
    try:
        pattern = r"el (.*?). El"
        result = re.search(pattern, raw_agent[0])
        string = result.group(1).strip().lower()
        format_string = string.replace('de','/').replace(' ','')
        if 'enero' in format_string:
            date =  format_string.replace('enero', '01')
        elif 'febrero' in format_string:
            date =  format_string.replace('febrero', '02')
        elif 'marzo' in format_string:
            date =  format_string.replace('marzo', '03')
        elif 'abril' in format_string:
            date =  format_string.replace('abril', '04')
        elif 'mayo' in format_string:
            date =  format_string.replace('mayo', '05')
        elif 'junio' in format_string:
            date =  format_string.replace('junio', '06')
        elif 'julio' in format_string:
            date =  format_string.replace('julio', '07')
        elif 'agosto' in format_string:
            date =  format_string.replace('agosto', '08')
        elif 'septiembre' in format_string:
            date =  format_string.replace('septiembre', '09')
        elif 'octubre' in format_string:
            date =  format_string.replace('octubre', '10')
        elif 'noviembre' in format_string:
            date =  format_string.replace('noviembre', '11')
        elif 'diciembre' in format_string:
            date =  format_string.replace('diciembre', '12')
        else:
            date = format_string
        return date[-10:]
    except:
        return np.nan

# %%
def dummies_comodities(df):
    # Separa los comodities y el ID en un nuevo dataframe y expande la lista de comodities en una unica fila de compinación id-comodity
    comodities = df[['comodities', 'id']].explode('comodities')
    # Genera el listado de variables dummies por todos los comodities 
    dummies = pd.get_dummies(comodities['comodities'])
    # Genera un df con los ids y las respectivas variables dummies, se une por el indice asi que no hay problema de que se corran los valores. Finalmente se agrupan por id.
    other_df = pd.concat([comodities['id'],dummies], axis=1).groupby('id').sum().reset_index().sort_values('id')
    # Se concatenan el df anterior y el original por ID
    final_df = df.merge(other_df, on='id', how='inner', sort='id')
    return final_df

# %%
def feature_columns(df):
    new_df = df.copy()
    new_df['id'] = new_df['code'].apply(transform_code)
    new_df['neighbourhood'] = new_df['location'].apply(transform_location)
    new_df['fixed_price'] = new_df['price'].apply(transform_price)
    new_df['stratum'] = new_df['details'].apply(lambda x: transform_detail_to(x, 0)).astype('float')
    new_df['type'] = new_df['details'].apply(lambda x: transform_detail_to(x, 1))
    new_df['status'] = new_df['details'].apply(lambda x: transform_detail_to(x, 2))
    new_df['bathrooms'] = new_df['details'].apply(lambda x: transform_detail_to(x, 3)).astype('float')
    new_df['built_area'] = new_df['details'].apply(lambda x: transform_detail_to_area(x,4))
    new_df['private_area'] = new_df['details'].apply(lambda x: transform_detail_to_area(x,5))
    new_df['age'] = new_df['details'].apply(lambda x: transform_detail_to(x, 6))
    new_df['rooms'] = new_df['details'].apply(lambda x: transform_detail_to(x, 7)).astype('float')
    new_df['rs_agent'] = new_df['real_state_agent'].apply(transform_agent)
    new_df['registered_date'] = pd.to_datetime(new_df['real_state_agent'].apply(transform_date), format='%d/%m/%Y', errors='coerce')
    new_df = dummies_comodities(new_df)
    new_df = new_df.drop(['location', 'price', 'details', 'real_state_agent', 'code', 'comodities'], axis=1)
    return new_df

# %%
df_cleaned = feature_columns(df)
df_cleaned.sample(3)
# Out:
#             id neighbourhood   fixed_price  stratum  type       status  \
# 531  191931678      Restrepo  1.500000e+09      3.0  Casa          NaN
# 965    7620436    Niza norte  1.400000e+09      5.0  Casa  Buen estado
# 103   10689378    Las cruces  4.500000e+08      3.0  Casa          NaN
#
#      bathrooms  built_area  private_area             age  rooms  \
# 531       10.0       400.0         126.0    16 a 30 años   11.0
# 965        3.0       428.0         428.0  más de 30 años    4.0
# 103        1.0       352.0         352.0  más de 30 años   15.0
#
#                        rs_agent registered_date  Acceso Pavimentado  \
# 531  inmobiliaria ruben quiroga      2025-01-28                   0
# 965               home elegance      2022-09-22                   0
# 103            liliana gonzalez      2024-03-13                   0
#
#      Aire Acondicionado  Alarma  Alarma Contra Incendio  Alcantarillado  \
# 531                   0       0                       0               0
# 965                   0       0                       0               0
# 103                   0       0                       0               0
#
#      Altura libre  Altura restringida  Amoblado  Asador  Ascensor  \
# 531             0                   0         0       0         0
# 965             0                   0         0       0         0
# 103             0                   0         0       0         0
#
#      Ascensor(es) inteligente(s)  Auditorio  Bahias de parqueo  \
# 531                            0          0                  0
# 965                            0          0                  0
# 103                            0          0                  0
#
#      Bahía exterior de parqueo  Balcón  Barra estilo americano  Baño Auxiliar  \
# 531                          0       0                       0              1
# 965                          0       0                       0              1
# 103                          0       0                       0              0
#
#      Baño Independiente  Baño compartido  Baño de Servicio  Baños Mixtos  \
# 531                   0                0                 0             0
# 965                   0                0                 0             0
# 103                   0                0                 0             0
#
#      Baños Públicos  Baños comunales  Bombas de gasolina  Bósque nativo  \
# 531               0                0                   0              0
# 965               0                0                   0              0
# 103               0                0                   0              0
#
#      Cableado de Red  Caldera  Calentador  Cancha de Baloncesto  \
# 531                0        0           1                     0
# 965                0        0           1                     0
# 103                0        0           0                     0
#
#      Cancha de Futbol  Cancha de Squash  Cancha de Tennis  Canchas Deportivas  \
# 531                 0                 0                 0                   0
# 965                 0                 0                 0                   0
# 103                 0                 0                 0                   0
#
#      Cerca a sector comercial  Cerca centro comercial  Cerca de Zona Urbana  \
# 531                         0                       0                     0
# 965                         0                       0                     0
# 103                         0                       0                     0
#
#      Chimenea  Circuito cerrado de TV  Citófono  Closet  Cochera  \
# 531         0                       0         0       0        0
# 965         1                       0         0       0        0
# 103         0                       0         0       0        0
#
#      Cocina Equipada  Cocina Integral  Cocina tipo Americano  Cocineta  \
# 531                0                1                      1         0
# 965                0                1                      1         0
# 103                0                0                      0         0
#
#      Colegios / Universidades  Comedor  Comedor auxiliar  Con Vivienda  \
# 531                         1        0                 0             0
# 965                         1        0                 1             0
# 103                         1        0                 0             0
#
#      Con administrador  Con casa club  Con cerca eléctrica  Control térmico  \
# 531                  0              0                    0                0
# 965                  0              0                    0                0
# 103                  0              0                    0                0
#
#      Cuarto de Escoltas  Cuarto de Servicio  Cuarto de conductores  \
# 531                   0                   0                      0
# 965                   0                   0                      0
# 103                   0                   0                      0
#
#      Cuarto de servicio  Cómodas vias de acceso  Depósito / Bodega  Despensa  \
# 531                   0                       0                  0         0
# 965                   0                       0                  1         1
# 103                   0                       0                  0         0
#
#      Disponibilidad WiFi  Duplex  Edificio Inteligente  En casa  \
# 531                    0       0                     0        0
# 965                    0       0                     0        0
# 103                    0       0                     0        0
#
#      En centro Comercial  En condominio  En conjunto cerrado  \
# 531                    0              0                    0
# 965                    0              0                    0
# 103                    0              0                    0
#
#      En zona Comercial  En zona residencial  Escalera de Emergencia  \
# 531                  0                    0                       0
# 965                  0                    0                       0
# 103                  0                    0                       0
#
#      Escaleras eléctricas  Esquinero  Estudio  Fuera de Centro Comercial  \
# 531                     0          0        0                          0
# 965                     0          0        1                          0
# 103                     0          0        0                          0
#
#      Garaje / Parqueadero(s)  Garaje Cubierto  Garaje(s)  Gimnasio  \
# 531                        0                0          1         0
# 965                        0                0          1         0
# 103                        0                0          0         0
#
#      Hall de Alcobas  Instalación de gas  Invernadero  Jardines Exteriores  \
# 531                0                   1            0                    0
# 965                1                   1            0                    0
# 103                0                   0            0                    0
#
#      Jardín  Kiosko  Lic. De construccion  Local Exterior  Local Interior  \
# 531       0       0                     0               0               0
# 965       1       0                     0               0               0
# 103       0       0                     0               0               0
#
#      Locales comerciales  Mezzanine  Oficina de negocios  \
# 531                    0          0                    0
# 965                    0          0                    0
# 103                    0          0                    0
#
#      Oficinas administrativas  Panorámica un lado  Parque industrial  \
# 531                         0                   0                  0
# 965                         0                   0                  0
# 103                         0                   0                  0
#
#      Parqueadero Visitantes  Parqueadero a Nivel  Parqueadero interno  \
# 531                       0                    0                    0
# 965                       0                    0                    0
# 103                       0                    0                    0
#
#      Parques cercanos  Patio  Patio Interno  Piscina  \
# 531                 0      1              0        0
# 965                 1      1              0        0
# 103                 0      0              0        0
#
#      Piso de alta resistencia  Piso en Alfombra  Piso en Baldosa /  Mármol  \
# 531                         0                 0                          1
# 965                         0                 0                          1
# 103                         0                 0                          0
#
#      Piso en Madera  Piso en cemento  Planta Eléctrica  Portería / Recepción  \
# 531               0                0                 0                     0
# 965               0                0                 0                     0
# 103               0                0                 0                     0
#
#      Portería / Vigilancia  Pozo de agua natural  Puerta de seguridad  \
# 531                      0                     0                    0
# 965                      0                     0                    0
# 103                      0                     0                    0
#
#      Restaurantes  Rio / Quebrada cercano(a)  Sala de internet  Salón Comunal  \
# 531             0                          0                 0              0
# 965             0                          0                 0              0
# 103             0                          0                 0              0
#
#      Salón de Juegos  Salón de videoconferencias  Sauna / Turco / Jacuzzi  \
# 531                0                           0                        0
# 965                0                           0                        0
# 103                0                           0                        0
#
#      Seguridad  Senderos ecológicos  Sensor de movimiento  \
# 531          0                    0                     0
# 965          0                    0                     0
# 103          0                    0                     0
#
#      Servicio de Internet  Servicio de Lavandería  Servicios Públicos  \
# 531                     0                       0                   0
# 965                     0                       0                   0
# 103                     0                       0                   0
#
#      Servicios independientes  Shut de basura  Sobre vía principal  \
# 531                         0               0                    1
# 965                         0               0                    0
# 103                         0               0                    1
#
#      Sobre vía secundaria  Soporte de grúas  Supermercados / C.Comerciales  \
# 531                     0                 0                              1
# 965                     0                 0                              1
# 103                     0                 0                              0
#
#      Sístema de riego  Tanques de Agua  Tarjetas Magnéticas  \
# 531                 0                0                    0
# 965                 0                0                    0
# 103                 0                0                    0
#
#      Tarjetas inteligentes  Terraza  Todos los Servicios  \
# 531                      0        1                    0
# 965                      0        1                    0
# 103                      0        0                    0
#
#      Trans. Público cercano  Ventilación Natural  Vigilancia  Vigilancia 24x7  \
# 531                       1                    0           0                0
# 965                       1                    0           1                0
# 103                       1                    0           0                0
#
#      Vigilancia privada 24*7  Vista panorámica  Vivienda Bifamiliar  \
# 531                        0                 1                    0
# 965                        0                 0                    0
# 103                        0                 0                    0
#
#      Vivienda Multifamiliar  Zona Campestre  Zona Comercial  Zona Industrial  \
# 531                       0               0               1                0
# 965                       0               0               0                0
# 103                       0               0               0                0
#
#      Zona Infantil  Zona Residencial  Zona de BBQ  Zona de Camping  \
# 531              0                 1            0                0
# 965              0                 1            0                0
# 103              0                 0            0                0
#
#      Zona de lavandería  Zonas Verdes  Árboles frutales  Área Urbana
# 531                   1             1                 0            0
# 965                   1             1                 0            0
# 103                   0             0                 0            0

# %%
df_cleaned.to_feather("../data/clened_houses_data.feather")

# %%
cleande_data = pd.read_feather("../data/clened_houses_data.feather")
